# %% [markdown]
# <a href="https://colab.research.google.com/github/Adrianus-Bagas/COVID-19-Detection/blob/main/COVID_19_Detection_(Demo).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deteksi Penyakit COVID-19 Melalui Citra CT-Scan

# %% [markdown]
# ## 1. Import beberapa libraries

# %%
from skimage import io
from keras.preprocessing import image
import numpy as np
from keras.models import load_model
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Memuat data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 3. Deteksi COVID-19

# %%
img = image.load_img('/content/drive/MyDrive/dataset/data COVID/COVID/Covid (56).png', grayscale=False, target_size=(64, 64))
show_img=image.load_img('/content/drive/MyDrive/dataset/data COVID/COVID/Covid (56).png', grayscale=False, target_size=(200, 200))
plt.imshow(show_img)
plt.show()

# %%
disease_class=['Non Covid-19','Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255
model = load_model('/content/drive/MyDrive/model/model densenet.h5')
custom = model.predict(x)
a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# Prediction: Covid-19
